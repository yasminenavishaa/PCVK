# %% [markdown]
# <a href="https://colab.research.google.com/github/yasminenavishaa/PCVK/blob/main/Week1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Laporan Praktikum Pertemuan 1 - Yasmine Navisha Andhani

# %% [markdown]
# ## Langkah (Step) 1 :

# %%
import numpy as np
import pandas as pd
import cv2 as cv
from google.colab.patches import cv2_imshow # for image display
from skimage import io
from skimage import transform
from PIL import Image
import matplotlib.pylab as plt

# %% [markdown]
# ## Langkah (Step) 2 :

# %%
# Membuat list untuk menyimpan url dari beberapa image
urls = ["https://iiif.lib.ncsu.edu/iiif/0052574/full/800,/0/default.jpg","https://iiif.lib.ncsu.edu/iiif/0016007/full/800,/0/default.jpg","https://placekitten.com/800/571"]
# baca dan tampilkan image
# loop pada tiap url image, beberapa image dapat disimpan pada list
for url in urls:
  image = io.imread(url)				                  #read image
  image = cv.resize(image, (0,0), fx=0.5, fy=0.5) #resize image to half size
  image_2 = cv.cvtColor(image, cv.COLOR_BGR2RGB)	#convert color to RGB
  final_frame = cv.hconcat((image, image_2))	    #concatenate image
  cv2_imshow(final_frame)				                  #show image
  print('\n')
# Out:
# <PIL.Image.Image image mode=RGB size=800x276>
# <PIL.Image.Image image mode=RGB size=800x286>
# <PIL.Image.Image image mode=RGB size=800x286>

# %% [markdown]
# ## Langkah (Step) 3 :
#
# melihat ukuran file image

# %%
tinggi = image_2.shape[0]
lebar = image_2.shape[1]
print("resolusi image: tinggi x lebar = ",tinggi," x ",lebar)
cv2_imshow(image_2)
# Out:
# resolusi image: tinggi x lebar =  286  x  400
# <PIL.Image.Image image mode=RGB size=400x286>

# %% [markdown]
# ## Langkah (Step) 4 :
#
# mengakses pixel dengan memberi garis diagonal menyilang

# %%
image_2 = cv.cvtColor(image, cv.COLOR_BGR2RGB)
image_3 = cv.cvtColor(image, cv.COLOR_BGR2RGB)

#membuat garis horizontal ditengah image
for y in range (lebar):
  image_3[int((tinggi)/2),y] = [255,255,255]

final_frame = cv.hconcat((image_2, image_3))
cv2_imshow(final_frame)
# Out:
# <PIL.Image.Image image mode=RGB size=800x286>

# %% [markdown]
# ## Pertanyaan
#
#
#
# 1. Jelaskan, Mengapa pada modul praktikum ini eksekusi kode phyton dilakukan menggunakan Google Colab?
#
# Jawab :
# 2. Jelaskan mengenai kegunaan setiap library pada praktikum langkah ke delapan?
# Apakah semua library tersebut harus digunakan dalam praktikum sesi ini?
#
# Jawab : Ya, semua library harus digunakan.
#
#
# *   Item daftar
# *   Item daftar
#
#
# 3. Pada uji coba langkah ke-9 terdapat potongan kode program sebagai berikut :
#
# ![image.png](data:image/png;base64,...)
#
# Apa kegunaan kode program tersebut? Dan apa pengaruhnya jika tidak dilakukan?
#
# Jawab :
#
# 4. Perhatikan potongan kode progam berikut :
#
# ![image.png](data:image/png;base64,...)
#
# Apakah kegunaan kode [255,255,255] ? Jelaskan!
#
# Jawab :
# 5. Jelaskan keterkaitan antara pixel dan juga resolusi gambar yang tinggi ataupun
# rendah!
#
# Jawab :

# %% [markdown]
# ## Tugas
#
# 1. Lakukan langkah-langkah praktikum seperti diatas
# 2. Buat garis vertikal dan garis menyilang diagonal pada image keluaran

# %%
image_2 = cv.cvtColor(image, cv.COLOR_BGR2RGB)
image_3 = cv.cvtColor(image, cv.COLOR_BGR2RGB)
image_4 = cv.cvtColor(image, cv.COLOR_BGR2RGB)

#membuat garis vertikal ditengah image

for y in range (tinggi):
  image_3[y, int(lebar/2)] = [255,255,255]

final_frame = cv.hconcat((image_2, image_3))
cv2_imshow(final_frame)

# Membuat garis diagonal pada image

for x in range(tinggi):
    image_4[x, int(x*(lebar/tinggi))] = [255, 255, 255]
    image_4[x, lebar - 1 - int(x*(lebar/tinggi))] = [255,255, 255]

final_frame = cv.hconcat((image_2, image_4))
cv2_imshow(final_frame)
# Out:
# <PIL.Image.Image image mode=RGB size=800x286>
# <PIL.Image.Image image mode=RGB size=800x286>

# %% [markdown]
# 3. Buat garis horisontal berwarna putih dibagian tengah gambar dengan panjang
# tertentu

# %%
image_5 = cv.cvtColor(image, cv.COLOR_BGR2RGB)
image_6 = cv.cvtColor(image, cv.COLOR_BGR2RGB)

# Menggambar garis horizontal putih di bagian tengah gambar dengan panjang tertentu

garis_posisi = tinggi // 2
garis_panjang = 60

image_6[garis_posisi, (lebar - garis_panjang) // 2 : (lebar + garis_panjang) // 2] = [255, 255, 255]

final_frame = cv.hconcat((image_5, image_6))
cv2_imshow(final_frame)
# Out:
# <PIL.Image.Image image mode=RGB size=800x286>

# %% [markdown]
# 4. Buat kotak menggunakan kumpulan pixel warna putih di sembarang tempat dalam
# gambar

# %%
image_5 = cv.cvtColor(image, cv.COLOR_BGR2RGB)
image_7 = cv.cvtColor(image, cv.COLOR_BGR2RGB)

# Menggambar garis horizontal putih di bagian tengah gambar dengan panjang tertentu

# Menentukan posisi kotak dan ukurannya
kotak_posisi_x = 120
kotak_posisi_y = 130
kotak_lebar = 150
kotak_tinggi = 100

image_7[kotak_posisi_y:kotak_posisi_y + kotak_tinggi, kotak_posisi_x:kotak_posisi_x + kotak_lebar] = [255, 255, 255]

final_frame = cv.hconcat((image_5, image_7))
cv2_imshow(final_frame)
# Out:
# <PIL.Image.Image image mode=RGB size=800x286>

# %% [markdown]
# ## Tugas Kelompok (Kelompok 8)
#
# Bentuk kelompok masing-masing terdiri dari 2-3 orang. tiap kelompok lakukan langkah berikut:

# %% [markdown]
# 1. Akses file image lokal (KTP/SIM) dan tampilkan menggunakan OpenCV dan Matplotlib

# %% [markdown]
# 2. Identifikasi kenapa menggunakan konversi warna BGR2RGB pada matplotlib dan tanpa konversi pada opencv
